# %%
from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns # biblioteca para gráficos mais apurados

# %%
df = pd.read_csv('titanic.csv')
# %matplotlib inline
df['Age'].value_counts().plot.bar(title = 'Idade por sexo')
plt.xlabel('Age')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
df['Cabin'].value_counts(ascending = True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Ticket'].value_counts(ascending = True).plot.pie()
# Out:
# <AxesSubplot:ylabel='Ticket'>

# %%
sns.heatmap(ship.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'Survived',data = ship)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>
